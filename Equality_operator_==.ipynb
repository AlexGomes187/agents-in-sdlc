# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexGomes187/agents-in-sdlc/blob/main/Equality_operator_%3D%3D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
car = "LDV"
print(car.lower( ) == "bmw")
# Out:
# False
