# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexGomes187/agents-in-sdlc/blob/main/Voting_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = float (input("What is your age? : "))

if age >= 18:
       print("You are eligable to vote.")
else:
        print("You are not eligible to vote yet.")
# Out:
# What is your age? : 18
# You are eligable to vote.
