# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexGomes187/agents-in-sdlc/blob/main/for_loop_%26_continue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#use string in a continue statement
#for loop
for letter in "Python" :
    if letter == "y":
       continue
    print("Letters in Python: " + letter)
print("Thank you.")
# Out:
# Letters in Python: P
# Letters in Python: t
# Letters in Python: h
# Letters in Python: o
# Letters in Python: n
# Thank you.
