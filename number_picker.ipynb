# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexGomes187/agents-in-sdlc/blob/main/number_picker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = float(input("Enter a number: "))

if number > 0:
       print("Positive")
elif number < 0:
      print("Negative")
else:
        print("Zero")
# Out:
# Enter a number: 22
# Positive
